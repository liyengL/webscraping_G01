# %%
import pandas as pd
import requests
import bs4
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
import nums_from_string
from selenium.common.exceptions import NoSuchElementException
import selenium.common.exceptions as selexcept
import numpy as np
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains

# %%
## Open browser
driver = webdriver.Chrome()
#Maximizing browser window to avoid hidden elements
driver.set_window_size(1024, 600)
driver.maximize_window()

# Set up the webdriver
driver = webdriver.Chrome()

# Navigate to SABI website
driver.get("https://esade.libguides.com/sabi")
time.sleep(3)
driver.find_element('xpath','/html/body/div[1]/div[2]/div[3]/div[3]/img').click()
time.sleep(2)
driver.find_element('xpath','/html/body/div[6]/div/form/div/div[1]/div/input').send_keys('kaho.wan@alumni.esade.edu')
driver.find_element('xpath','/html/body/div[6]/div/form/div/div[2]/div/input').send_keys('Fofi2john6wan?')
time.sleep(2)
driver.find_element('xpath','/html/body/div[6]/div/form/div/div[3]/span[1]').click()

#If already login, click on restart, otherwise do nothing
time.sleep(4)

try:
    driver.find_element('xpath','/html/body/form/div/div/div[2]/div[3]/div/div/table/tbody/tr[2]/td/input').click()
    
except:
    pass

# %%
#location
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[7]').click()
time.sleep(2)
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_QuickSearch1_ctl02_SearchSearchMenu_Menu1"]/li[7]/ul/li[1]').click()
time.sleep(2)
#get into the selection page
#select spain
driver.find_element('xpath','/html/body/form/div[6]/div/div[2]/table/tbody/tr/td[1]/div/div[3]/table/tbody/tr/td/div/div/div[2]/div/div/table/tbody/tr[9]/td/div/table/tbody/tr/td[2]').click()
time.sleep(1.5)
#going back to homepage
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_Ok"]').click()
time.sleep(1.5)
#fliter industry
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[8]').click()
time.sleep(1.5)
# select the 3rd drop down - industry classifications
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[8]/ul/li[3]').click()
time.sleep(0.5)
# click the 1th classification 
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr[6]/td[1]/div[2]/div/div/div/table/tbody/tr[01]/td/div/table/tbody/tr/td[2]/table/tbody/tr/td[1]/img').click()
time.sleep(0.5)
#click on okay button
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_Ok"]').click()
time.sleep(0.5)
# Click the "view list of results"
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_QuickSearch1_ctl05_GoToList"]').click()
time.sleep(0.5)
#Add columns
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_ListHeader_ListHeaderRightButtons_AddRemoveColumns"]').click()
time.sleep(2)
#Now we are in the add columns interface we can add the variables:
#click on the 1st column
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[1]/td[2]/img[1]').click()
time.sleep(0.5)
#click ok (switch of iframe is important)
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()

#clck on 2(identification number)-7(account header)

#2click on identification number
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[3]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()
time.sleep(0.5)

#3
# first click the + icon to expand it
driver.find_element('xpath', '//*[@id="GROUP_LEGAL_ACCOUNT_NodeImg"]').click()
# check the legal information box
driver.find_element('xpath', '/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[6]/td[2]/table/tbody/tr[1]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
#click ok
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()
time.sleep(0.5)
#check the account information box
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[6]/td[2]/table/tbody/tr[3]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()
time.sleep(0.5)

#4 Size and group info
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[7]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()
time.sleep(0.5)

#5 Brands
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[9]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()
time.sleep(0.5)

#6 Industry ad activities
#click on +
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[11]/td[1]').click()
time.sleep(0.2)
#click on all industry classification
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[12]/td[2]/table/tbody/tr[1]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()
time.sleep(0.5)
#click on all peer review
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[12]/td[2]/table/tbody/tr[3]/td[2]/img[1]').click()
time.sleep(0.1)
#click on all overview
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[12]/td[2]/table/tbody/tr[5]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()
time.sleep(0.5)

#7 accounts header
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[13]/td[2]/img[1]').click()
# click absolute year
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
#2022- 2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[1]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()
time.sleep(1.0)

# click the "global" okay button to keep our selection and take us back to the main table page
driver.find_element('xpath',"//*[@id='ContentContainer1_ctl00_Content_SaveFormat_OkButton']").click()

# %%
#click on export
driver.find_element('xpath',"/html/body/form/div[6]/table/tbody/tr[2]/td/div/table/tbody/tr[2]/td/table/tbody/tr[1]/td[2]/div[1]/table/tbody/tr/td[7]/div/table/tbody/tr/td[1]/ul").click()
time.sleep(3)

# Get the handles of all open windows
handles = driver.window_handles

# Switch to the new window
driver.switch_to.window(handles[-1])

#click on excel
driver.find_element('xpath',"/html/body/form/table[2]/tbody/tr/td/table/tbody/tr[2]/td[1]/select/option[1]").click()

#click on limiting pages
driver.find_element('xpath',"/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[1]/input").click()

#enter number
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[2]/input").send_keys('1')
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[4]/input").send_keys('1000')

time.sleep(1)

# %%
#manually click on okay

# %%
# Switch back to the original window
driver.switch_to.window(handles[0])

# %%
#click on x here to clean import as using clean all doesnt work here(no clue how to click the pop up ok)

# %%
#repeating the very first few steps to continue on selecting 8(financial)
#location
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[7]').click()
time.sleep(2)
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_QuickSearch1_ctl02_SearchSearchMenu_Menu1"]/li[7]/ul/li[1]').click()
time.sleep(2)
#get into the selection page
#select spain
driver.find_element('xpath','/html/body/form/div[6]/div/div[2]/table/tbody/tr/td[1]/div/div[3]/table/tbody/tr/td/div/div/div[2]/div/div/table/tbody/tr[9]/td/div/table/tbody/tr/td[2]').click()
time.sleep(1.5)
#going back to homepage
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_Ok"]').click()
time.sleep(1.5)
#fliter industry
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[8]').click()
time.sleep(1.5)
# select the 3rd drop down - industry classifications
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[8]/ul/li[3]').click()
time.sleep(1.5)

# click the 1th classification 
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr[6]/td[1]/div[2]/div/div/div/table/tbody/tr[01]/td/div/table/tbody/tr/td[2]/table/tbody/tr/td[1]/img').click()
time.sleep(0.5)
#click on okay button
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_Ok"]').click()
time.sleep(0.5)

# Click the "view list of results"
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_QuickSearch1_ctl05_GoToList"]').click()
time.sleep(0.5)

#Add columns
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_ListHeader_ListHeaderRightButtons_AddRemoveColumns"]').click()
time.sleep(2)
#Now we are in the add columns interface we can add the variables:
#click on the 1st column
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[1]/td[2]/img[1]').click()
time.sleep(0.5)
#click ok (switch of iframe is important)
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()

# %%
#8 financials
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[15]/td[1]').click()
#click on key financials
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[16]/td[2]/table/tbody/tr[1]/td[2]/img[1]').click()
#click on absolute year
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
#2022-2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[1]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()

driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()

#click on + in global format
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[16]/td[2]/table/tbody/tr[3]/td[1]').click()
    #click on balance sheet
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[16]/td[2]/table/tbody/tr[4]/td[2]/table/tbody/tr[1]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
    #2022-2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[1]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()

driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()

    #click on income statement
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[16]/td[2]/table/tbody/tr[4]/td[2]/table/tbody/tr[3]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
    #2022-2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[1]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()

driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()

    #click on + in European ratio
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[16]/td[2]/table/tbody/tr[5]/td[1]').click()

    #click on profitability
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[16]/td[2]/table/tbody/tr[6]/td[2]/table/tbody/tr[1]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
#2022-2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[1]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()

driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()


    #click on operations
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[16]/td[2]/table/tbody/tr[6]/td[2]/table/tbody/tr[3]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
#2022-2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[1]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()

driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()

    #click on structure
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[16]/td[2]/table/tbody/tr[6]/td[2]/table/tbody/tr[5]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
#2022-2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[1]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()

driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()

    #click on per employee
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[16]/td[2]/table/tbody/tr[6]/td[2]/table/tbody/tr[7]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
#2022-2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[1]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()

driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()

#click on variation rate
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[16]/td[2]/table/tbody/tr[7]/td[2]/img[1]').click()
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
#2022-2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[1]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()

driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()

    #click on + in detailed format
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[16]/td[2]/table/tbody/tr[9]/td[1]').click()

    #click on + in Spain
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[16]/td[2]/table/tbody/tr[10]/td[2]/table/tbody/tr[1]/td[1]').click()

# %%
# click the "global" okay button to keep our selection and take us back to the main table page
driver.find_element('xpath',"//*[@id='ContentContainer1_ctl00_Content_SaveFormat_OkButton']").click()

# %%
#click on export
driver.find_element('xpath',"/html/body/form/div[6]/table/tbody/tr[2]/td/div/table/tbody/tr[2]/td/table/tbody/tr[1]/td[2]/div[1]/table/tbody/tr/td[7]/div/table/tbody/tr/td[1]/ul").click()
time.sleep(3)

# Get the handles of all open windows
handles = driver.window_handles

# Switch to the new window
driver.switch_to.window(handles[-1])

#click on excel
driver.find_element('xpath',"/html/body/form/table[2]/tbody/tr/td/table/tbody/tr[2]/td[1]/select/option[1]").click()

#click on limiting pages
driver.find_element('xpath',"/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[1]/input").click()

#enter number
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[2]/input").send_keys('1')
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[4]/input").send_keys('1000')

time.sleep(1)

# %%
##manually click on okay then close it after downloading

# %%
# Switch back to the original window
driver.switch_to.window(handles[0])

# %%
#click on x here to clean import as using clean all doesnt work here(no clue how to click the pop up ok)

# %%
#repeating the very first few steps to continue on selecting 8(financial)
#location
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[7]').click()
time.sleep(2)
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_QuickSearch1_ctl02_SearchSearchMenu_Menu1"]/li[7]/ul/li[1]').click()
time.sleep(2)
#get into the selection page
#select spain
driver.find_element('xpath','/html/body/form/div[6]/div/div[2]/table/tbody/tr/td[1]/div/div[3]/table/tbody/tr/td/div/div/div[2]/div/div/table/tbody/tr[9]/td/div/table/tbody/tr/td[2]').click()
time.sleep(1.5)
#going back to homepage
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_Ok"]').click()
time.sleep(1.5)
#fliter industry
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[8]').click()
time.sleep(1.5)
# select the 3rd drop down - industry classifications
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[8]/ul/li[3]').click()
time.sleep(1.5)

# click the 1th classification 
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr[6]/td[1]/div[2]/div/div/div/table/tbody/tr[01]/td/div/table/tbody/tr/td[2]/table/tbody/tr/td[1]/img').click()
time.sleep(0.5)
#click on okay button
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_Ok"]').click()
time.sleep(0.5)

# Click the "view list of results"
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_QuickSearch1_ctl05_GoToList"]').click()
time.sleep(0.5)

#Add columns
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_ListHeader_ListHeaderRightButtons_AddRemoveColumns"]').click()
time.sleep(2)
#Now we are in the add columns interface we can add the variables:
#click on the 1st column
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[1]/td[2]/img[1]').click()
time.sleep(0.5)
#click ok (switch of iframe is important)
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()

# %%
#add payments incidents
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[17]/td[1]').click()
time.sleep(1.0)

#click on spain
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[18]/td[2]/table/tbody/tr[1]/td[2]/img[1]').click()
time.sleep(1.0)

#click on employee segmentation
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[19]/td[1]').click()
time.sleep(1.0)
#click on spain
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[20]/td[2]/table/tbody/tr[1]/td[2]/img[1]').click()
time.sleep(1.0)
#click on absolute year
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
time.sleep(1.0)
#2022- 2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[1]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()
time.sleep(1.0)
driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()

# %%
#stockdata
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[21]/td[1]').click()

# %%
#click on security & price information
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[1]/td[1]').click()
time.sleep(0.5)
#click on listing status
driver.find_element('xpath','//html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[2]/td[2]/table/tbody/tr[1]/td[2]/img').click()
time.sleep(0.5)
#click on currency - delisting notes
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[2]/td[2]/table/tbody/tr[2]/td[2]/img').click()
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[2]/td[2]/table/tbody/tr[3]/td[2]/img').click()
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[2]/td[2]/table/tbody/tr[4]/td[2]/img').click()
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td[2]/img').click()
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[2]/td[2]/table/tbody/tr[6]/td[2]/img').click()
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td[2]/img').click()
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[2]/td[2]/table/tbody/tr[8]/td[2]/img').click()
time.sleep(1.0)

#click on okay
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()


driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[2]/td[2]/table/tbody/tr[9]/td[2]/img').click()
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[2]/td[2]/table/tbody/tr[10]/td[2]/img').click()
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[2]/td[2]/table/tbody/tr[11]/td[2]/img').click()
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[2]/td[2]/table/tbody/tr[12]/td[2]/img').click()

# %%
# click the "global" okay button to keep our selection and take us back to the main table page
driver.find_element('xpath',"//*[@id='ContentContainer1_ctl00_Content_SaveFormat_OkButton']").click()

# %%
#click on export
driver.find_element('xpath',"/html/body/form/div[6]/table/tbody/tr[2]/td/div/table/tbody/tr[2]/td/table/tbody/tr[1]/td[2]/div[1]/table/tbody/tr/td[7]/div/table/tbody/tr/td[1]/ul").click()
time.sleep(3)

# Get the handles of all open windows
handles = driver.window_handles

# Switch to the new window
driver.switch_to.window(handles[-1])

#click on excel
driver.find_element('xpath',"/html/body/form/table[2]/tbody/tr/td/table/tbody/tr[2]/td[1]/select/option[1]").click()

#click on limiting pages
driver.find_element('xpath',"/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[1]/input").click()

#enter number
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[2]/input").send_keys('1')
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[4]/input").send_keys('1000')

time.sleep(1)

# %%
#manually click on okay then close it

# %%
# Switch back to the original window
driver.switch_to.window(handles[0])

# %%
# click on x here to clean import as using clean all doesnt work here(no clue how to click the pop up ok)

# %%
#repeating the very first few steps
#location
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[7]').click()
time.sleep(2)
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_QuickSearch1_ctl02_SearchSearchMenu_Menu1"]/li[7]/ul/li[1]').click()
time.sleep(2)
#get into the selection page
#select spain
driver.find_element('xpath','/html/body/form/div[6]/div/div[2]/table/tbody/tr/td[1]/div/div[3]/table/tbody/tr/td/div/div/div[2]/div/div/table/tbody/tr[9]/td/div/table/tbody/tr/td[2]').click()
time.sleep(1.5)
#going back to homepage
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_Ok"]').click()
time.sleep(1.5)
#fliter industry
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[8]').click()
time.sleep(1.5)
# select the 3rd drop down - industry classifications
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[8]/ul/li[3]').click()
time.sleep(1.5)

# click the 1th classification 
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr[6]/td[1]/div[2]/div/div/div/table/tbody/tr[01]/td/div/table/tbody/tr/td[2]/table/tbody/tr/td[1]/img').click()
time.sleep(0.5)
#click on okay button
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_Ok"]').click()
time.sleep(0.5)

# Click the "view list of results"
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_QuickSearch1_ctl05_GoToList"]').click()
time.sleep(0.5)

#Add columns
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_ListHeader_ListHeaderRightButtons_AddRemoveColumns"]').click()
time.sleep(2)
#Now we are in the add columns interface we can add the variables:
#click on the 1st column
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[1]/td[2]/img[1]').click()
time.sleep(0.5)
#click ok (switch of iframe is important)
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()

# %%
#stockdata
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[21]/td[1]').click()

# %%
#click current stock data
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[3]/td[2]/img[1]').click()

#click on okay
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()
time.sleep(1.0)
#click annual stock data
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[5]/td[2]/img[1]').click()
time.sleep(1.0)
#click on absolute year
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
time.sleep(1.0)
#2022- 2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[6]/td/span/input').click()

driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()

time.sleep(1.0)
#clicn annual stock valuation
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[9]/td[2]/img[1]').click()
#click on absolute year
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
time.sleep(1.0)
#2022- 2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[6]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()
time.sleep(1.0)

#click daily pricing
driver.find_element('xpath','//html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[22]/td[2]/table/tbody/tr[15]/td[2]/img[1]').click()
#click on absolute year
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
time.sleep(1.0)
#click all months
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[2]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr/td[1]/input').click()
#unclick 01/2023
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[1]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[4]/div/div[2]/input').click()
driver.switch_to.default_content()

# %%
# click the "global" okay button to keep our selection and take us back to the main table page
driver.find_element('xpath',"//*[@id='ContentContainer1_ctl00_Content_SaveFormat_OkButton']").click()

# %%
#click on export
driver.find_element('xpath',"/html/body/form/div[6]/table/tbody/tr[2]/td/div/table/tbody/tr[2]/td/table/tbody/tr[1]/td[2]/div[1]/table/tbody/tr/td[7]/div/table/tbody/tr/td[1]/ul").click()
time.sleep(3)

# Get the handles of all open windows
handles = driver.window_handles

# Switch to the new window
driver.switch_to.window(handles[-1])

#click on excel
driver.find_element('xpath',"/html/body/form/table[2]/tbody/tr/td/table/tbody/tr[2]/td[1]/select/option[1]").click()

#click on limiting pages
driver.find_element('xpath',"/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[1]/input").click()

#enter number
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[2]/input").send_keys('1')
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[4]/input").send_keys('971')

time.sleep(1)

# %%
#manually click on okay the wait to close it after downloading

# %%
#manually click on okay then close it 
# Switch back to the original window
driver.switch_to.window(handles[0])

# %%
#click on export
driver.find_element('xpath',"/html/body/form/div[6]/table/tbody/tr[2]/td/div/table/tbody/tr[2]/td/table/tbody/tr[1]/td[2]/div[1]/table/tbody/tr/td[7]/div/table/tbody/tr/td[1]/ul").click()
time.sleep(3)

# Get the handles of all open windows
handles = driver.window_handles

# Switch to the new window
driver.switch_to.window(handles[-1])

#click on excel
driver.find_element('xpath',"/html/body/form/table[2]/tbody/tr/td/table/tbody/tr[2]/td[1]/select/option[2]").click()

#click on limiting pages
driver.find_element('xpath',"/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[1]/input").click()

#enter number
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[2]/input").send_keys('972')
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[4]/input").send_keys('1000')

time.sleep(1)

#click on ok
driver.find_element('xpath',"/html/body/form/div[5]/div[2]/div[3]/div/span").click()

# %%
#manually click on okay then close it

# %%
# Switch back to the original window
driver.switch_to.window(handles[0])

# %%
#click on x here to clean import as using clean all doesnt work here(no clue how to click the pop up ok)

# %%
#repeating the very first few steps
#location
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[7]').click()
time.sleep(2)
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_QuickSearch1_ctl02_SearchSearchMenu_Menu1"]/li[7]/ul/li[1]').click()
time.sleep(2)
#get into the selection page
#select spain
driver.find_element('xpath','/html/body/form/div[6]/div/div[2]/table/tbody/tr/td[1]/div/div[3]/table/tbody/tr/td/div/div/div[2]/div/div/table/tbody/tr[9]/td/div/table/tbody/tr/td[2]').click()
time.sleep(1.5)
#going back to homepage
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_Ok"]').click()
time.sleep(1.5)
#fliter industry
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[8]').click()
time.sleep(1.5)
# select the 3rd drop down - industry classifications
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr/td/div[2]/table/tbody/tr/td/table/tbody/tr/td/div/div[2]/div[2]/div/table/tbody/tr/td/div/table[1]/tbody/tr[2]/td/div/table/tbody/tr[1]/td[2]/ul/li[8]/ul/li[3]').click()
time.sleep(1.5)

# click the 1th classification 
driver.find_element('xpath','/html/body/form/div[6]/div[2]/table/tbody/tr[6]/td[1]/div[2]/div/div/div/table/tbody/tr[01]/td/div/table/tbody/tr/td[2]/table/tbody/tr/td[1]/img').click()
time.sleep(0.5)
#click on okay button
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_Ok"]').click()
time.sleep(0.5)

# Click the "view list of results"
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_QuickSearch1_ctl05_GoToList"]').click()
time.sleep(0.5)

#Add columns
driver.find_element('xpath','//*[@id="ContentContainer1_ctl00_Content_ListHeader_ListHeaderRightButtons_AddRemoveColumns"]').click()
time.sleep(2)
#Now we are in the add columns interface we can add the variables:
#click on the 1st column
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[1]/td[2]/img[1]').click()
time.sleep(0.5)
#click ok (switch of iframe is important)
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()

# %%
#click on director/contactor/advisor
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[23]/td[1]').click()

#click on auditor
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[24]/td[2]/table/tbody/tr[3]/td[2]/img[1]').click()

#click ok okay
#click on okay
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()
time.sleep(1.0)
#click on auditor per year
driver.find_element('xpath','/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[24]/td[2]/table/tbody/tr[5]/td[2]/img[1]').click()
#click on okay
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()
time.sleep(1.0)
#click on banks
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[24]/td[2]/table/tbody/tr[7]/td[2]/img[1]").click()
#click on okay
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()
time.sleep(1.0)

#board
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[25]/td[2]/img[1]").click()
time.sleep(1.0)
#click on absolute year
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[1]/td/div/div/div[1]/div[1]/a').click()
time.sleep(1.0)
#2022- 2018
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[1]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[2]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[3]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[4]/td/span/input').click()
driver.find_element('xpath','/html/body/form/div[3]/div/table/tbody/tr[1]/td[1]/div/table/tbody/tr/td/table/tbody/tr[3]/td/div/div[1]/table/tbody/tr/td/div/table/tbody/tr[5]/td/span/input').click()
time.sleep(1.0)
#click on okay
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()

# %%
#leasing
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[27]/td[1]").click()
#click on leasing
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[28]/td[2]/table/tbody/tr[1]/td[2]/img[1]").click()
#click on okay
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()
time.sleep(1.0)
#click on banking operations
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[28]/td[2]/table/tbody/tr[3]/td[2]/img[1]").click()
#click on okay
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()
time.sleep(1.0)
#click on government grants
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[28]/td[2]/table/tbody/tr[5]/td[2]/img[1]").click()
#click on okay
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()
time.sleep(1.0)

# %%
#ownership
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[29]/td[1]").click()
#click on no of companies in corporate group
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[1]/td[2]").click()
#click on shareholder
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[2]/td[1]").click()
time.sleep(1.0)
#click on general information
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[3]/td[2]/table/tbody/tr[1]/td[2]/img[1]").click()
#clikc on immediate parent information
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[3]/td[2]/table/tbody/tr[3]/td[2]/img[1]").click()
time.sleep(1.0)
#click on global ultimate owner information
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[3]/td[2]/table/tbody/tr[5]/td[2]/img[1]").click()
#click on domestic ultimate owner information
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[3]/td[2]/table/tbody/tr[7]/td[2]/img[1]").click()
#click on controlling shareholders
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[3]/td[2]/table/tbody/tr[9]/td[2]/img[1]").click()
time.sleep(1.0)
#click on okay
iframe = driver.find_element('xpath',"//iframe[@id='frameFormatOptionDialog']")
driver.switch_to.frame(iframe)
driver.find_element('xpath',"/html/body/form/div[4]/div/div[2]/input").click()
driver.switch_to.default_content()
time.sleep(1.0)
#click on subsidiary
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[4]/td[1]").click()
#click on general information
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[5]/td[2]/table/tbody/tr[1]/td[2]/img[1]").click()
time.sleep(0.5)
#click on subsidiary
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[5]/td[2]/table/tbody/tr[3]/td[2]/img[1]").click()
#click on branches and headquarters
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[6]/td[1]").click()
time.sleep(1.0)
#click on branches
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[7]/td[2]/table/tbody/tr[1]/td[2]/img[1]").click()
#click on headquarters
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[30]/td[2]/table/tbody/tr[7]/td[2]/table/tbody/tr[3]/td[2]/img[1]").click()
time.sleep(0.5)
#click on headquarters
#braches
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[31]/td[2]/img[1]").click()
time.sleep(1.0)

# %%
#news and deals
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[33]/td[1]").click()
time.sleep(1.0)
#click on links to news and deals
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[34]/td[2]/table/tbody/tr[1]/td[2]/img[1]").click()
time.sleep(1.0)
#various
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[35]/td[2]/img[1]").click()
time.sleep(1.0)
#notes
driver.find_element('xpath',"/html/body/form/div[6]/div[4]/div[2]/div[2]/div[1]/div/div[1]/table/tbody/tr[37]/td[2]/img[1]").click()
time.sleep(1.0)
# click the "global" okay button to keep our selection and take us back to the main table page
driver.find_element('xpath',"//*[@id='ContentContainer1_ctl00_Content_SaveFormat_OkButton']").click()
time.sleep(1.0)

# %%
#click on export
driver.find_element('xpath',"/html/body/form/div[6]/table/tbody/tr[2]/td/div/table/tbody/tr[2]/td/table/tbody/tr[1]/td[2]/div[1]/table/tbody/tr/td[7]/div/table/tbody/tr/td[1]/ul").click()
time.sleep(3)

# Get the handles of all open windows
handles = driver.window_handles

# Switch to the new window
driver.switch_to.window(handles[-1])

#click on excel
driver.find_element('xpath',"/html/body/form/table[2]/tbody/tr/td/table/tbody/tr[2]/td[1]/select/option[1]").click()

#click on limiting pages
driver.find_element('xpath',"/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[1]/input").click()

#enter number
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[2]/input").send_keys('1')
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[4]/input").send_keys('492')

time.sleep(1)

# %%
#click on okay then close it

# %%
# Switch back to the original window
driver.switch_to.window(handles[0])

# %%
#click on export
driver.find_element('xpath',"/html/body/form/div[6]/table/tbody/tr[2]/td/div/table/tbody/tr[2]/td/table/tbody/tr[1]/td[2]/div[1]/table/tbody/tr/td[7]/div/table/tbody/tr/td[1]/ul").click()
time.sleep(3)

# Get the handles of all open windows
handles = driver.window_handles

# Switch to the new window
driver.switch_to.window(handles[-1])

#click on excel
driver.find_element('xpath',"/html/body/form/table[2]/tbody/tr/td/table/tbody/tr[2]/td[1]/select/option[1]").click()

#click on limiting pages
driver.find_element('xpath',"/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[1]/input").click()

#enter number
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[2]/input").send_keys('493')
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[4]/input").send_keys('950')

time.sleep(1)

# %%
#click on okay then close it

# %%
# Switch back to the original window
driver.switch_to.window(handles[0])

# %%
#click on export
driver.find_element('xpath',"/html/body/form/div[6]/table/tbody/tr[2]/td/div/table/tbody/tr[2]/td/table/tbody/tr[1]/td[2]/div[1]/table/tbody/tr/td[7]/div/table/tbody/tr/td[1]/ul").click()
time.sleep(3)

# Get the handles of all open windows
handles = driver.window_handles

# Switch to the new window
driver.switch_to.window(handles[-1])

#click on excel
driver.find_element('xpath',"/html/body/form/table[2]/tbody/tr/td/table/tbody/tr[2]/td[1]/select/option[1]").click()

#click on limiting pages
driver.find_element('xpath',"/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[1]/input").click()

#enter number
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[2]/input").send_keys('951')
driver.find_element("xpath","/html/body/form/table[1]/tbody/tr[2]/td/table/tbody/tr[5]/td/table/tbody/tr/td[4]/input").send_keys('1000')

time.sleep(1)

# %%
#click on okay then close it

# %%
# Switch back to the original window
driver.switch_to.window(handles[0])
